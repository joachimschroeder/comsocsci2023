# %% [markdown]
# # Overview
#
# This week we'll talk about some of the charachteristics of real-world social networks. The structure is the following:
#
# * Part 1: A crash course on real-world social networks.
# * Part 2: Visualizing the network of Computational Social Scientists
# * Part 3: Properties of the real-world network of Computational Social Scientists
#
#
# > *Reading*: Read [Chapter 3 of the Network Science book.](http://networksciencebook.com/chapter/3). The most important sections are 3.1 to 3.4 and 3.8 to 3.10, so focus on that.

# %% [markdown]
# # Part 1 : Empirical properties of real-world social networks

# %% [markdown]
# Researchers in Computational Social Science have widely studied the properties of real-world social networks. The very cool thing they found is that many widely different social networks (from face-to-face interactions among classmates, to the Facebook network, to collaboration networks among scientists, etc) present some commonalities. We refer to those as 'Universalities'.
# In the video-lecture below, I will introduce _some_ of the things we know to be true for most real-world social networks.

# %% [markdown]
# >> **_Video Lecture_**. Start by watching the ["Properties of empirical social networks"](https://youtu.be/jHdnehLku54).

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("jHdnehLku54",width=800, height=450)

# %% [markdown]
# > *Exercise 1:* Did you really read the text? Answer the following questions (no calculations needed) in your Jupyter notebook.
#
# > * What's the problem with random networks as a model for real-world networks according to the argument in section 3.5 (near the end)?
# > * List the four regimes that characterize random networks as a function of ⟨k⟩.
# > * According to the book, why is it a problem for random networks (in terms of being a model for real-world networks that the degree-dependent clustering C(k) decreases as a function of k in real-world networks?

# %% [markdown]
# # Part 2 : Visualizing the network of Computational Social Scientists

# %% [markdown]
# Take the network of Computational Social Scientists you built in Week4.
# To get an idea about how the network looks like, we start visualizing it. For this exercise, we will use the __awesome library [``netwulf``](https://netwulf.readthedocs.io/en/latest/index.html)__ created by Ulf Aslak and Ben Maier, two colleagues of mine.
# You can install it via ``pip install netwulf``.
#
# Netwulf is built on top of [d3-force](https://github.com/d3/d3-force), a Javascript library that simulates the dynamics of particles moving in 2D. In the visualization, particles correspond to network nodes subject to forces:
#  * Nodes are attracted to the center of the viz
#  * Nodes repel each other
#  * Nodes linked by an edge will preferably stay at a fixed distance to each other.
#
# Come and ask me if you want to know more!

# %% [markdown]
# > _Exercise_ 1: Visualize the network of Computational Social scientists.
# >
# > * Extract the [largest connected components](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.components.connected_components.html) from your network.
# > * Visualize the largest connected component using the function [``visualize``](https://netwulf.readthedocs.io/en/latest/reference/interactive.html?highlight=visualize#netwulf.interactive.visualize) of the Netwulf package.
# > * Play with the parameters of the netwulf algorithm to obtain a visualization you like. To understand better what the parameters mean, have a look at the [documentation](https://netwulf.readthedocs.io/en/latest/visualization/init.html?). Your visualization may look similar to the one below, where I made the size of nodes proportional to their strength (sum of weights of incoming edges), and I added the names of the top Computational Social Scientists by degree... But not necessarily! Just have fun making your own version. You can save the figure directly from the interactive visualization panel, or plot it in higher resolution in matplotlib following [this example](https://netwulf.readthedocs.io/en/latest/cookbook/cookbook.html#save-as-pdf).
# > * Describe the structure you observe. Can you identify nodes with a privileged position in the network?
# > * _Optional_: You can color nodes based on a property of your interest. For example, I colored nodes based on the top discipline, following [this example](https://github.com/benmaier/netwulf/issues/38). What do you observe? Can you find specific nodes properties that seem to correlate with a node's position in the network?
#
# <img src="https://github.com/lalessan/comsocsci2023/raw/master/figures/network.png" alt="Drawing" style="width: 800px;"/>

# %%
import pickle 
import numpy as np
import pandas as pd
import networkx as nx
import netwulf as nw


author_data = pd.read_csv('../author_data.csv')
author_data.head()
# Out:
#           ids                      names  \
# 0     2773799               A. Filisetti
# 1  1399712184          S. Cohen-Boulakia
# 2    50197963                  J. Ludwig
# 3     3530609                   L. Dutra
# 4    84242025  Annelies E. M. van Vianen
#
#                                              aliases  citationCount  \
# 0            ['A Filisetti', 'Alessandro Filisetti']            631
# 1  ['S Cohen-boulakia', 'Sarah Cohen‐boulakia', '...            757
# 2                       ['J. Ludwig', 'Jens Ludwig']          11446
# 3  ['Lívia Macedo Dutra', 'Lívia M. Dutra', 'Lívi...            477
# 4  ['Annelies Elizabeth Maria Van Vianen', 'Annel...           2035
#
#               field
# 0           Biology
# 1  Computer Science
# 2         Economics
# 3         Chemistry
# 4        Psychology

# %%
author_data['ids'] = author_data['ids'].astype(str)
author_data['field'] = author_data['field'].astype(str)

# %%
with open('CSS.pkl', 'rb') as f:
    G = pickle.load(f)

# %%
nw.visualize(G)
# Out:
# (None, None)

# %%
names_init = dict(zip(list(G.nodes), ['unknonwn']*len(list(G.nodes))))
fields_init = dict(zip(list(G.nodes), ['unknonwn']*len(list(G.nodes))))
names = dict(author_data[["ids","names"]].values)
names_init.update(names)
fields = dict(author_data[["ids","field"]].values)
fields_init.update(fields)
nx.set_node_attributes(G, names_init, 'name')
nx.set_node_attributes(G, fields_init, 'field')

# %%
fields
# Out:
# {'2773799': 'Biology',
#  '1399712184': 'Computer Science',
#  '50197963': 'Economics',
#  '3530609': 'Chemistry',
#  '84242025': 'Psychology',
#  '2931137': 'Biology',
#  '52278908': 'Computer Science',
#  '79604936': 'Medicine',
#  '1774221': 'Computer Science',
#  '1661057657': 'Biology',
#  '3376613': 'Psychology',
#  '144327496': 'Economics',
#  '12896311': 'Psychology',
#  '13314950': 'Medicine',
#  '2071524389': 'Psychology',
#  '7555661': 'Education',
#  '31384989': 'Engineering',
#  '49361540': 'Art',
#  '2065362430': 'Materials Science',
#  '1681853': 'Business',
#  '2474463': 'Biology',
#  '5522902': 'Education',
#  '1411830334': 'Psychology',
#  '2065223957': 'Business',
#  '2051584284': 'Medicine',
#  '2059407446': 'Education',
#  '40478606': 'Biology',
#  '1936964': 'Physics',
#  '49916135': 'Physics',
#  '152457254': 'Sociology',
#  '117656902': 'Physics',
#  '50778658': 'Art',
#  '2073003810': 'Medicine',
#  '13875073': 'Medicine',
#  '145941081': 'Computer Science',
#  '49198638': 'Computer Science',
#  '49095156': 'Agricultural And Food Sciences',
#  '84009858': 'Agricultural And Food Sciences',
#  '2116052969': 'Computer Science',
#  '121110395': 'Environmental Science',
#  '11260552': 'Physics',
#  '3790368': 'Education',
#  '33962131': 'Medicine',
#  '40571041': 'Environmental Science',
#  '1749176': 'Medicine',
#  '2139261': 'Medicine',
#  '2034446': 'Medicine',
#  '150047590': 'Psychology',
#  '2029239952': 'nan',
#  '145617351': 'Medicine',
#  '145475096': 'Medicine',
#  '2115490461': 'Education',
#  '48890651': 'Physics',
#  '2065120622': 'nan',
#  '1399547013': 'Medicine',
#  '16007478': 'Medicine',
#  '2169118364': 'Psychology',
#  '40583075': 'Mathematics',
#  '108279842': 'Geography',
#  '152385054': 'Physics',
#  '49107685': 'Computer Science',
#  '50667569': 'Education',
#  '3450563': 'Engineering',
#  '2572821': 'Psychology',
#  '10689883': 'Economics',
#  '8914645': 'Medicine',
#  '117450704': 'Economics',
#  '122782866': 'Medicine',
#  '4807153': 'Biology',
#  '39978955': 'Medicine',
#  '103261195': 'Physics',
#  '93156370': 'nan',
#  '1704422': 'Computer Science',
#  '5689899': 'Computer Science',
#  '4195354': 'Medicine',
#  '2116341479': 'Mathematics',
#  '2134820143': 'Medicine',
#  '4139040': 'Economics',
#  '145538692': 'Biology',
#  '113269026': 'Medicine',
#  '145526289': 'Medicine',
#  '70439330': 'Computer Science',
#  '1758372': 'Medicine',
#  '2016220783': 'Psychology',
#  '9248489': 'Environmental Science',
#  '1714834': 'Computer Science',
#  '145526880': 'Physics',
#  '119340774': 'Political Science',
#  '2352183': 'Psychology',
#  '2185854566': 'Physics',
#  '146682501': 'Mathematics',
#  '1411725677': 'Medicine',
#  '152447213': 'Medicine',
#  '1686529': 'Computer Science',
#  '30815957': 'Environmental Science',
#  '1396029681': 'Medicine',
#  '47268066': 'Medicine',
#  '31492326': 'Psychology',
#  '1775192': 'Computer Science',
#  '79326821': 'Psychology',
#  '4046510': 'Medicine',
#  '83932476': 'Biology',
#  '30406408': 'Medicine',
#  '2066216451': 'Computer Science',
#  '144473638': 'Computer Science',
#  '71424532': 'Education',
#  '2145900839': 'Business',
#  '2053417944': 'Computer Science',
#  '2086466630': 'nan',
#  '101142344': 'Physics',
#  '49953381': 'Philosophy',
#  '1704709': 'Computer Science',
#  '1706272': 'Computer Science',
#  '2110894650': 'Computer Science',
#  '3679274': 'Psychology',
#  '2111384200': 'Medicine',
#  '143946382': 'Education',
#  '50153677': 'Computer Science',
#  '13643850': 'Computer Science',
#  '2118105821': 'Biology',
#  '3517369': 'Psychology',
#  '32345932': 'Environmental Science',
#  '94856448': 'Business',
#  '30682542': 'Psychology',
#  '93396129': 'Medicine',
#  '114099438': 'Biology',
#  '7448691': 'Environmental Science',
#  '5820854': 'Medicine',
#  '39651651': 'Computer Science',
#  '28935180': 'Computer Science',
#  '144008299': 'Medicine',
#  '2146699258': 'Computer Science',
#  '31982777': 'Computer Science',
#  '121043437': 'nan',
#  '2060782081': 'Medicine',
#  '47938601': 'Computer Science',
#  '9132078': 'Computer Science',
#  '33350589': 'nan',
#  '2517620': 'Psychology',
#  '2050499': 'Philosophy',
#  '2502468': 'Environmental Science',
#  '2152441601': 'Agricultural And Food Sciences',
#  '145439442': 'Physics',
#  '4339782': 'Biology',
#  '143937326': 'Medicine',
#  '6038049': 'Physics',
#  '1741418956': 'Education',
#  '144873271': 'Biology',
#  '100624017': 'Sociology',
#  '68975437': 'Computer Science',
#  '145091933': 'Computer Science',
#  '2111465906': 'Medicine',
#  '2109174501': 'Computer Science',
#  '2188901506': 'Engineering',
#  '2111567259': 'Medicine',
#  '47524879': 'Biology',
#  '32239020': 'Medicine',
#  '1808760': 'Computer Science',
#  '2766898': 'Chemistry',
#  '3995594': 'Environmental Science',
#  '95093756': 'Environmental Science',
#  '2057941530': 'nan',
#  '34988748': 'Mathematics',
#  '19307744': 'Psychology',
#  '46215119': 'Business',
#  '1402974706': 'Psychology',
#  '2150023604': 'Computer Science',
#  '47516484': 'Biology',
#  '2059178132': 'Computer Science',
#  '2144470753': 'Engineering',
#  '122480668': 'Physics',
#  '4358753': 'Biology',
#  '2554068': 'Business',
#  '10055136': 'Medicine',
#  '1743965': 'Computer Science',
#  '2862178': 'Computer Science',
#  '66594372': 'Computer Science',
#  '152575661': 'Engineering',
#  '52275752': 'Psychology',
#  '144464805': 'Medicine',
#  '4536818': 'Computer Science',
#  '3810909': 'Medicine',
#  '2072983494': 'Agricultural And Food Sciences',
#  '46899275': 'Computer Science',
#  '9842589': 'Medicine',
#  '40020226': 'Materials Science',
#  '98027048': 'Education',
#  '2108762580': 'Biology',
#  '46769532': 'History',
#  '2082915315': 'Sociology',
#  '3164641': 'Psychology',
#  '3757972': 'Biology',
#  '3969507': 'Physics',
#  '2479927': 'Education',
#  '2022914': 'Mathematics',
#  '32374267': 'Medicine',
#  '14081251': 'nan',
#  '145277525': 'Computer Science',
#  '7444483': 'Psychology',
#  '5464590': 'Medicine',
#  '117182555': 'Psychology',
#  '2325780': 'Psychology',
#  '66862935': 'Economics',
#  '1431226552': 'Computer Science',
#  '2166777040': 'Computer Science',
#  '144446653': 'Computer Science',
#  '1719537': 'Computer Science',
#  '90655813': 'Computer Science',
#  '1693493': 'Medicine',
#  '2440937': 'Biology',
#  '4700838': 'Medicine',
#  '115092117': 'Biology',
#  '89619519': 'nan',
#  '3078712': 'Medicine',
#  '88403296': 'nan',
#  '150266698': 'Medicine',
#  '2148459099': 'nan',
#  '144923981': 'Engineering',
#  '112997731': 'Education',
#  '7648294': 'Mathematics',
#  '2060562540': 'Biology',
#  '145764887': 'Computer Science',
#  '15138858': 'Medicine',
#  '113634480': 'Physics',
#  '2157576598': 'Biology',
#  '47159899': 'Medicine',
#  '107631980': 'History',
#  '116592244': 'Economics',
#  '2841201': 'Business',
#  '1683278': 'Philosophy',
#  '3599544': 'Medicine',
#  '35264592': 'Computer Science',
#  '49406328': 'Biology',
#  '4916944': 'Medicine',
#  '2108422258': 'Computer Science',
#  '30210596': 'History',
#  '15199202': 'Education',
#  '2003338023': 'Computer Science',
#  '113145194': 'Business',
#  '49478623': 'Business',
#  '2146695726': 'Economics',
#  '2006359891': 'nan',
#  '35076892': 'nan',
#  '9506860': 'Computer Science',
#  '13083245': 'Psychology',
#  '81448770': 'nan',
#  '1768569': 'Computer Science',
#  '2054042264': 'nan',
#  '17872871': 'Medicine',
#  '31857456': 'Medicine',
#  '5020350': 'Medicine',
#  '31039282': 'Medicine',
#  '3102898': 'Computer Science',
#  '14657101': 'Business',
#  '1768540': 'Computer Science',
#  '2126105283': 'Medicine',
#  '8833440': 'Agricultural And Food Sciences',
#  '1721147': 'Business',
#  '2140904149': 'Political Science',
#  '39544679': 'Computer Science',
#  '3332698': 'Computer Science',
#  '1400481887': 'Medicine',
#  '34367928': 'Medicine',
#  '143806654': 'nan',
#  '1576240700': 'Psychology',
#  '2269109': 'Computer Science',
#  '2093344985': 'Psychology',
#  '32584310': 'Medicine',
#  '5003917': 'Medicine',
#  '2109047879': 'Biology',
#  '1396370403': 'Political Science',
#  '70303173': 'Computer Science',
#  '144167816': 'nan',
#  '34568508': 'Engineering',
#  '2155516305': 'Medicine',
#  '50209311': 'Computer Science',
#  '77987296': 'nan',
#  '47166531': 'Economics',
#  '144426053': 'Physics',
#  '83124498': 'Medicine',
#  '145503012': 'Materials Science',
#  '2024040': 'Philosophy',
#  '2151642310': 'Biology',
#  '39541268': 'Computer Science',
#  '67050364': 'Economics',
#  '153431568': 'Education',
#  '145355531': 'Medicine',
#  '81284438': 'Medicine',
#  '123799656': 'Medicine',
#  '2108878942': 'Business',
#  '105013767': 'Environmental Science',
#  '2068242277': 'Environmental Science',
#  '47074461': 'Computer Science',
#  '1780115': 'Art',
#  '52358206': 'Medicine',
#  '47607453': 'Computer Science',
#  '1741928': 'Computer Science',
#  '13747499': 'Medicine',
#  '46454863': 'Medicine',
#  '12675253': 'Political Science',
#  '49112642': 'Biology',
#  '3278308': 'Economics',
#  '26385137': 'Computer Science',
#  '1702551': 'Computer Science',
#  '9186315': 'Business',
#  '75171216': 'Sociology',
#  '3182302': 'Computer Science',
#  '2179506917': 'Medicine',
#  '49431559': 'Political Science',
#  '2064451179': 'nan',
#  '2085350365': 'nan',
#  '46996266': 'Physics',
#  '1398011712': 'Medicine',
#  '122837566': 'Computer Science',
#  '2107728357': 'Medicine',
#  '144858370': 'Medicine',
#  '2108667981': 'Medicine',
#  '102372108': 'Physics',
#  '3271692': 'Computer Science',
#  '35658394': 'Medicine',
#  '143953987': 'Business',
#  '47860614': 'Medicine',
#  '1742395566': 'Medicine',
#  '2169562637': 'nan',
#  '2237909': 'Computer Science',
#  '2182662131': 'Medicine',
#  '1651608234': 'Medicine',
#  '80327755': 'Psychology',
#  '2069189387': 'Medicine',
#  '2058299940': 'Medicine',
#  '153581398': 'Biology',
#  '4257088': 'Biology',
#  '153820138': 'Biology',
#  '152191355': 'Materials Science',
#  '144228318': 'Materials Science',
#  '5350008': 'Biology',
#  '1708900': 'Computer Science',
#  '145340749': 'Biology',
#  '3908091': 'Biology',
#  '39885859': 'Computer Science',
#  '2047280274': 'nan',
#  '104227323': 'nan',
#  '38809346': 'Medicine',
#  '1444699639': 'Computer Science',
#  '2089786458': 'Medicine',
#  '48416103': 'Physics',
#  '3427009': 'Business',
#  '143741691': 'Economics',
#  '34958184': 'Biology',
#  '3991497': 'Medicine',
#  '2083804536': 'nan',
#  '40153616': 'Biology',
#  '98590740': 'Biology',
#  '144595006': 'Computer Science',
#  '51241198': 'Education',
#  '48936827': 'Geology',
#  '2141445364': 'Medicine',
#  '8194860': 'Biology',
#  '37144265': 'Biology',
#  '2133508200': 'Education',
#  '145181187': 'Biology',
#  '1986356851': 'Computer Science',
#  '81036365': 'Biology',
#  '11580857': 'Biology',
#  '145994734': 'Medicine',
#  '50655657': 'Psychology',
#  '2197373157': 'Medicine',
#  '5403453': 'Medicine',
#  '15845853': 'Physics',
#  '120297210': 'Medicine',
#  '117165584': 'Psychology',
#  '40179513': 'Biology',
#  '2692229': 'Computer Science',
#  '143742406': 'Computer Science',
#  '49887003': 'Agricultural And Food Sciences',
#  '2059587031': 'Sociology',
#  '2335829': 'Biology',
#  '15571836': 'Psychology',
#  '15714345': 'Political Science',
#  '145525220': 'Sociology',
#  '35585319': 'Computer Science',
#  '1404182545': 'Environmental Science',
#  '49550733': 'Computer Science',
#  '34899387': 'Medicine',
#  '2576905': 'Computer Science',
#  '2107059963': 'Environmental Science',
#  '2158257271': 'Computer Science',
#  '119387506': 'Psychology',
#  '145474614': 'Medicine',
#  '90061889': 'Psychology',
#  '2093146648': 'Psychology',
#  '1399114225': 'Psychology',
#  '1498988865': 'Psychology',
#  '2081814865': 'Medicine',
#  '1762757': 'Computer Science',
#  '3113641': 'Economics',
#  '2139216429': 'Medicine',
#  '1459885008': 'Psychology',
#  '2149189218': 'Physics',
#  '4844310': 'Psychology',
#  '152607415': 'Physics',
#  '2118124150': 'Biology',
#  '89304735': 'Computer Science',
#  '39716563': 'Computer Science',
#  '1951645': 'Medicine',
#  '1397938361': 'Psychology',
#  '1399265316': 'Environmental Science',
#  '1825401': 'Medicine',
#  '6978022': 'Biology',
#  '3052879': 'Computer Science',
#  '46278594': 'Psychology',
#  '2110230345': 'Computer Science',
#  '2543320': 'Medicine',
#  '1959433': 'Engineering',
#  '4573308': 'Medicine',
#  '38402076': 'Medicine',
#  '50592296': 'Education',
#  '2037328350': 'Business',
#  '6190347': 'Computer Science',
#  '48549677': 'Medicine',
#  '101395559': 'Physics',
#  '6774521': 'Physics',
#  '144226508': 'Biology',
#  '6194175': 'Biology',
#  '100979850': 'Art',
#  '4557020': 'Medicine',
#  '1513806565': 'Environmental Science',
#  '40894110': 'Environmental Science',
#  '46306202': 'Medicine',
#  '2598812': 'Computer Science',
#  '1596825714': 'Economics',
#  '3294328': 'Computer Science',
#  '48068927': 'Biology',
#  '122930173': 'nan',
#  '6948291': 'Biology',
#  '40278842': 'Business',
#  '2073020': 'Medicine',
#  '152330751': 'Medicine',
#  '2202499903': 'Political Science',
#  '66153199': 'Medicine',
#  '41053191': 'Agricultural And Food Sciences',
#  '2112682660': 'Computer Science',
#  '4471764': 'Physics',
#  '38902241': 'Medicine',
#  '2194359': 'Computer Science',
#  '1402168491': 'Biology',
#  '41197857': 'History',
#  '2113687827': 'Medicine',
#  '2691095': 'Computer Science',
#  '144897583': 'Physics',
#  '2648489': 'Medicine',
#  '104278936': 'Environmental Science',
#  '51462314': 'Business',
#  '3490057': 'Engineering',
#  '2317757': 'Psychology',
#  '1954346': 'Business',
#  '51453829': 'Medicine',
#  '80643475': 'Medicine',
#  '51442987': 'Chemistry',
#  '1992129': 'Medicine',
#  '107958545': 'Sociology',
#  '13978600': 'Economics',
#  '1678174043': 'Medicine',
#  '2023275': 'Computer Science',
#  '6675507': 'Medicine',
#  '3180936': 'Biology',
#  '83521829': 'Medicine',
#  '13826414': 'Environmental Science',
#  '152367159': 'Computer Science',
#  '2060357205': 'Political Science',
#  '6995588': 'Biology',
#  '1380233174': 'Computer Science',
#  '50160363': 'Medicine',
#  '2087348': 'Economics',
#  '2192600': 'Economics',
#  '133797370': 'Psychology',
#  '48333867': 'Biology',
#  '1696678': 'Computer Science',
#  '143954898': 'Medicine',
#  '4905577': 'Biology',
#  '4701593': 'Medicine',
#  '2109431845': 'Biology',
#  '2167693054': 'Physics',
#  '46452772': 'Materials Science',
#  '50197417': 'Computer Science',
#  '152158553': 'Medicine',
#  '5131628': 'Computer Science',
#  '2051582583': 'Medicine',
#  '8065182': 'Computer Science',
#  '33648375': 'Chemistry',
#  '2057470969': 'Chemistry',
#  '2109964017': 'Physics',
#  '145861075': 'Medicine',
#  '2064780042': 'nan',
#  '40373626': 'Education',
#  '1698107208': 'Computer Science',
#  '144932516': 'Physics',
#  '46299998': 'Psychology',
#  '2084599173': 'Computer Science',
#  '78292535': 'Environmental Science',
#  '1393229896': 'Computer Science',
#  '2054534358': 'Art',
#  '2112556236': 'Economics',
#  '2157627599': 'Computer Science',
#  '2650673': 'Computer Science',
#  '1491627343': 'Computer Science',
#  '3707815': 'Medicine',
#  '145036961': 'Computer Science',
#  '2135690744': 'Computer Science',
#  '88920777': 'Medicine',
#  '66023589': 'nan',
#  '2695365': 'Computer Science',
#  '67212612': 'Biology',
#  '4579675': 'Medicine',
#  '2052614922': 'Computer Science',
#  '34512768': 'Computer Science',
#  '2161602774': 'Biology',
#  '2024232408': 'Materials Science',
#  '2067641876': 'Computer Science',
#  '1402994497': 'Psychology',
#  '39448893': 'Economics',
#  '4622371': 'Medicine',
#  '1764577': 'Computer Science',
#  '143750986': 'Biology',
#  '5556487': 'Medicine',
#  '2703501': 'Business',
#  '33382073': 'Political Science',
#  '3298275': 'Computer Science',
#  '36523028': 'Biology',
#  '26263426': 'Psychology',
#  '143951292': 'Economics',
#  '1728757': 'Computer Science',
#  '3753219': 'Linguistics',
#  '89225780': 'Biology',
#  '113618294': 'Biology',
#  '1701475': 'Computer Science',
#  '3981024': 'Environmental Science',
#  '4897370': 'Biology',
#  '103771349': 'Political Science',
#  '1404827955': 'Medicine',
#  '23164629': 'Business',
#  '9796442': 'Medicine',
#  '49864381': 'Medicine',
#  '2901051': 'Psychology',
#  '2007386': 'Psychology',
#  '114435638': 'Sociology',
#  '143772714': 'Computer Science',
#  '1616286760': 'Medicine',
#  '2152516472': 'Materials Science',
#  '23677649': 'Chemistry',
#  '31932266': 'Business',
#  '2161986932': 'Computer Science',
#  '51481213': 'Psychology',
#  '147220776': 'Business',
#  '3914689': 'Physics',
#  '35119676': 'Physics',
#  '51981622': 'Medicine',
#  '153430661': 'Business',
#  '90634881': 'Chemistry',
#  '2056096161': 'Medicine',
#  '3065561': 'Medicine',
#  '77046151': 'Economics',
#  '2054105217': 'Computer Science',
#  '11624107': 'Agricultural And Food Sciences',
#  '2068985449': 'nan',
#  '2889408': 'Computer Science',
#  '1881433577': 'Medicine',
#  '2108958127': 'Medicine',
#  '10726446': 'Mathematics',
#  '2064761997': 'Computer Science',
#  '37475276': 'Medicine',
#  '2055907071': 'Medicine',
#  '2807137': 'Economics',
#  '3525914': 'Chemistry',
#  '101352315': 'Computer Science',
#  '23285477': 'Computer Science',
#  '3459091': 'Computer Science',
#  '2016261': 'Computer Science',
#  '2118278039': 'Medicine',
#  '47614714': 'Medicine',
#  '12513531': 'Geology',
#  '7975032': 'Computer Science',
#  '144171563': 'Computer Science',
#  '1411733238': 'Medicine',
#  '152977405': 'Medicine',
#  '1660424138': 'Business',
#  '4454619': 'Physics',
#  '2062768143': 'Medicine',
#  '4486242': 'Medicine',
#  '3170013': 'Computer Science',
#  '1814094': 'Computer Science',
#  '2868135': 'Computer Science',
#  '10733398': 'Computer Science',
#  '7660878': 'Computer Science',
#  '6434409': 'Medicine',
#  '47462149': 'Medicine',
#  '104541442': 'Economics',
#  '2076499': 'Computer Science',
#  '6889922': 'Medicine',
#  '74109766': 'nan',
#  '28706409': 'Psychology',
#  '48817189': 'Psychology',
#  '145283199': 'Computer Science',
#  '6783999': 'Biology',
#  '145311615': 'Medicine',
#  '97633638': 'Materials Science',
#  '2106045176': 'Biology',
#  '34944421': 'Engineering',
#  '49166962': 'Computer Science',
#  '2108245734': 'Computer Science',
#  '2118796174': 'Biology',
#  '50084715': 'Medicine',
#  '120432835': 'Biology',
#  '25519352': 'Psychology',
#  '2910658': 'Computer Science',
#  '34829897': 'Physics',
#  '143662654': 'Physics',
#  '3938148': 'Medicine',
#  '145093565': 'Medicine',
#  '145739210': 'Medicine',
#  '2107487862': 'Medicine',
#  '39696980': 'Medicine',
#  '9584121': 'Biology',
#  '144651240': 'History',
#  '2066070727': 'Computer Science',
#  '2107728661': 'Medicine',
#  '2182619990': 'nan',
#  '2170327296': 'Biology',
#  '40655309': 'Computer Science',
#  '1387872181': 'Computer Science',
#  '8779563': 'Chemistry',
#  '108445377': 'nan',
#  '71248407': 'Political Science',
#  '33412481': 'Medicine',
#  '152469179': 'Physics',
#  '46969949': 'Medicine',
#  '123673628': 'nan',
#  '2073961988': 'nan',
#  '29368432': 'Computer Science',
#  '5609311': 'Medicine',
#  '3870775': 'Medicine',
#  '8338373': 'Biology',
#  '116614431': 'Engineering',
#  '41227565': 'Physics',
#  '32876290': 'Computer Science',
#  '10222832': 'Biology',
#  '145768494': 'Medicine',
#  '3065617': 'Computer Science',
#  '40150465': 'Economics',
#  '144005242': 'Biology',
#  '145465220': 'Computer Science',
#  '121691611': 'nan',
#  '49688225': 'Art',
#  '4889158': 'Biology',
#  '153079946': 'Computer Science',
#  '146984765': 'nan',
#  '143863052': 'Physics',
#  '11367797': 'Economics',
#  '39496312': 'Computer Science',
#  '2106299762': 'Psychology',
#  '2074816168': 'Psychology',
#  '1958263': 'Computer Science',
#  '1693370300': 'Computer Science',
#  '1892247': 'Computer Science',
#  '1917661': 'Biology',
#  '145323445': 'Computer Science',
#  '3086323': 'Economics',
#  '22600925': 'Medicine',
#  '2157481947': 'Agricultural And Food Sciences',
#  '81349205': 'Biology',
#  '9400137': 'Engineering',
#  '3443469': 'Computer Science',
#  '2067433157': 'Geology',
#  '89651121': 'Psychology',
#  '144849745': 'Education',
#  '3027593': 'Computer Science',
#  '80423343': 'Computer Science',
#  '145838181': 'Mathematics',
#  '121605377': 'Economics',
#  '6528416': 'Medicine',
#  '2075475075': 'Biology',
#  '8002182': 'Medicine',
#  '2144063165': 'Materials Science',
#  '151061394': 'Medicine',
#  '40021520': 'Biology',
#  '2073060839': 'nan',
#  '1740595': 'Computer Science',
#  '2073728281': 'Computer Science',
#  '32356174': 'Biology',
#  '2957648': 'Agricultural And Food Sciences',
#  '2519428': 'Medicine',
#  '1402806484': 'Biology',
#  '143967564': 'Biology',
#  '6756770': 'Medicine',
#  '6120438': 'Medicine',
#  '40020645': 'Medicine',
#  '2802746': 'Business',
#  '40991168': 'Psychology',
#  '123101245': 'Medicine',
#  '2148758917': 'Engineering',
#  '27980717': 'Psychology',
#  '2909056': 'Computer Science',
#  '47741304': 'Biology',
#  '1912100': 'Computer Science',
#  '2135038869': 'Medicine',
#  '2743320': 'Biology',
#  '3009366': 'Computer Science',
#  '14419314': 'Medicine',
#  '2022952837': 'Computer Science',
#  '1573737253': 'Business',
#  '1713102': 'Computer Science',
#  '40894019': 'Education',
#  '144722242': 'Computer Science',
#  '1779247': 'Business',
#  '7952128': 'Education',
#  '2111931': 'Computer Science',
#  '48327383': 'Computer Science',
#  '91654989': 'Biology',
#  '51131601': 'Computer Science',
#  '51975392': 'Medicine',
#  '1705574': 'Computer Science',
#  '72400560': 'nan',
#  '1576487520': 'History',
#  '2113903047': 'Medicine',
#  '2053832474': 'Law',
#  '2130189678': 'Medicine',
#  '2901648': 'Computer Science',
#  '3787781': 'Biology',
#  '152170662': 'Physics',
#  '108660343': 'Environmental Science',
#  '1750780': 'Computer Science',
#  '115605782': 'Medicine',
#  '70495855': 'Economics',
#  '24748037': 'Art',
#  '2059441513': 'Biology',
#  '2065585461': 'Computer Science',
#  '48920527': 'Medicine',
#  '123378943': 'Political Science',
#  '2249096': 'Medicine',
#  '2059699704': 'Computer Science',
#  '5168792': 'Biology',
#  '3546194': 'Biology',
#  '34937247': 'Economics',
#  '115002806': 'Medicine',
#  '1403346810': 'Computer Science',
#  '3883781': 'Medicine',
#  '50641825': 'Medicine',
#  '2115947019': 'Biology',
#  '1412378990': 'Medicine',
#  '9542883': 'Computer Science',
#  '2079678295': 'nan',
#  '2089563938': 'Education',
#  '2057206133': 'Medicine',
#  '50714971': 'Environmental Science',
#  '2290001': 'Political Science',
#  '5711242': 'Medicine',
#  '2755349': 'Engineering',
#  '78971030': 'Computer Science',
#  '87452309': 'Medicine',
#  '102778042': 'Engineering',
#  '5272409': 'Medicine',
#  '48952848': 'Medicine',
#  '92341957': 'Psychology',
#  '4727109': 'Medicine',
#  '46808784': 'Biology',
#  '51350188': 'Medicine',
#  '13285228': 'Medicine',
#  '2101429485': 'nan',
#  '2637887': 'Computer Science',
#  '121470161': 'nan',
#  '21814254': 'Physics',
#  '2084622985': 'Biology',
#  '65739089': 'Psychology',
#  '37719915': 'Medicine',
#  '102593096': 'Sociology',
#  '2095755551': 'Computer Science',
#  '13644301': 'Economics',
#  '3205957': 'Computer Science',
#  '66586437': 'Economics',
#  '2075317746': 'Medicine',
#  '2144439426': 'Chemistry',
#  '118277418': 'Medicine',
#  '2026267633': 'Computer Science',
#  '2097650852': 'Medicine',
#  '2080764666': 'Geology',
#  '103122749': 'Physics',
#  '2133468043': 'Computer Science',
#  '92188844': 'Engineering',
#  '40330225': 'Business',
#  '2086855463': 'Medicine',
#  '73242929': 'nan',
#  '48506843': 'Medicine',
#  '4028693': 'Business',
#  '2880599': 'Business',
#  '145865822': 'Medicine',
#  '2140116999': 'Economics',
#  '83986808': 'nan',
#  '5691238': 'Medicine',
#  '1399489670': 'Medicine',
#  '2184913': 'Computer Science',
#  '5877752': 'Biology',
#  '7425978': 'Medicine',
#  '2206272': 'Business',
#  '3009678': 'Computer Science',
#  '2154871510': 'Computer Science',
#  '2035210': 'Medicine',
#  '116097781': 'Art',
#  '40372667': 'Biology',
#  '6091316': 'Medicine',
#  '11862825': 'Materials Science',
#  '40240138': 'Biology',
#  '32579948': 'Economics',
#  '67007124': 'Psychology',
#  '104826009': 'Medicine',
#  '2119401667': 'Economics',
#  '2137221311': 'Business',
#  '6429584': 'Medicine',
#  '107897505': 'Materials Science',
#  '2066440923': 'Philosophy',
#  '96629356': 'nan',
#  '2065220244': 'Computer Science',
#  '5059942': 'Medicine',
#  '2076216872': 'nan',
#  '13023866': 'Medicine',
#  '46570525': 'Medicine',
#  '153710264': 'Computer Science',
#  '146023810': 'Medicine',
#  '1581283020': 'nan',
#  '2124192040': 'Medicine',
#  '1429576533': 'Medicine',
#  '2906658': 'Computer Science',
#  '117856906': 'Psychology',
#  '41196550': 'Physics',
#  '1873461761': 'Medicine',
#  '4126514': 'Sociology',
#  '145139498': 'Medicine',
#  '46280513': 'Sociology',
#  '1757272': 'Computer Science',
#  '4797260': 'Psychology',
#  '47035386': 'Psychology',
#  '1700537': 'Computer Science',
#  '2113194962': 'Medicine',
#  '2064882699': 'Medicine',
#  '51282716': 'Chemistry',
#  '49638944': 'Computer Science',
#  '152940813': 'Economics',
#  '1380844516': 'Medicine',
#  '2116489667': 'Environmental Science',
#  '2184437': 'Computer Science',
#  '2060167953': 'Mathematics',
#  '2074302751': 'Computer Science',
#  '121903005': 'Psychology',
#  '2905745': 'Computer Science',
#  '98367205': 'Computer Science',
#  '2054853464': 'Environmental Science',
#  '2151706': 'Environmental Science',
#  '143834921': 'Computer Science',
#  '2052696985': 'Computer Science',
#  '34820574': 'Computer Science',
#  '1927474': 'Art',
#  '114076780': 'Political Science',
#  '145597855': 'Psychology',
#  '3609225': 'Medicine',
#  '3915127': 'Philosophy',
#  '2147103356': 'Environmental Science',
#  '144667508': 'Engineering',
#  '120231217': 'Physics',
#  '1644980190': 'Psychology',
#  '2204364289': 'Medicine',
#  '15470742': 'Medicine',
#  '2066280421': 'Education',
#  '1787959': 'Computer Science',
#  '32571228': 'Biology',
#  '5113888': 'Medicine',
#  '6969769': 'Medicine',
#  '150324514': 'Computer Science',
#  '2503659': 'Computer Science',
#  '2441164': 'Biology',
#  '144151551': 'Medicine',
#  '3192857': 'Physics',
#  '49056245': 'Medicine',
#  '2557668': 'Computer Science',
#  '119650188': 'Computer Science',
#  '2675413': 'Psychology',
#  '2399811': 'Medicine',
#  '35204937': 'Biology',
#  '2055189477': 'nan',
#  '13922398': 'Medicine',
#  '1690892': 'Computer Science',
#  '2202144650': 'Computer Science',
#  '116458391': 'History',
#  '143784235': 'Medicine',
#  '90077567': 'Agricultural And Food Sciences',
#  '81520170': 'Medicine',
#  '39241869': 'History',
#  '10348489': 'Economics',
#  '2080391617': 'nan',
#  '10800713': 'Economics',
#  '1715452': 'Biology',
#  '145116440': 'Computer Science',
#  '6971536': 'Medicine',
#  '1969733': 'Physics',
#  '2187601': 'Computer Science',
#  '51101325': 'Medicine',
#  '144248389': 'Economics',
#  '2038358727': 'Materials Science',
#  '31301666': 'Medicine',
#  '50349827': 'nan',
#  '36829053': 'Medicine',
#  '153851463': 'Medicine',
#  '2065439295': 'Computer Science',
#  '123058008': 'Medicine',
#  '40632770': 'Psychology',
#  '47171304': 'Physics',
#  '2954536': 'Physics',
#  '2106532172': 'nan',
#  '144180010': 'Psychology',
#  '1382616872': 'Physics',
#  '144199960': 'Medicine',
#  '2054175637': 'Biology',
#  '14279477': 'Medicine',
#  '39673779': 'Psychology',
#  '2118404658': 'Education',
#  '2070420412': 'Computer Science',
#  '15914188': 'Medicine',
#  '145869901': 'Medicine',
#  '147466394': 'nan',
#  '2187560319': 'Business',
#  '120028908': 'Education',
#  '2110816662': 'Computer Science',
#  '2931616': 'Business',
#  '2065196983': 'Psychology',
#  '35716748': 'Psychology',
#  '2113754434': 'nan',
#  '34592453': 'Medicine',
#  '50708404': 'Computer Science',
#  '2173025418': 'Education',
#  '11290242': 'Environmental Science',
#  '1388775854': 'Computer Science',
#  '2059942145': 'nan',
#  '2363728': 'Biology',
#  '22707919': 'Environmental Science',
#  '2268622': 'Psychology',
#  '4173848': 'Physics',
#  '2889457': 'Computer Science',
#  '103769103': 'Computer Science',
#  '146017354': 'Computer Science',
#  '108154548': 'Environmental Science',
#  '1729223405': 'Medicine',
#  '2323042': 'Biology',
#  '2262595': 'Computer Science',
#  '1413512609': 'Psychology',
#  '1771991': 'Medicine',
#  '81224767': 'Computer Science',
#  '5744161': 'Medicine',
#  '2109614017': 'Medicine',
#  '2152797417': 'Medicine',
#  '5903846': 'Computer Science',
#  '153226268': 'Medicine',
#  '3213962': 'Computer Science',
#  '1687220': 'Computer Science',
#  '133969473': 'Political Science',
#  '1846129': 'Computer Science',
#  '2497087': 'Sociology',
#  '144823982': 'Environmental Science',
#  '1685771': 'Computer Science',
#  '47226056': 'Computer Science',
#  '48373930': 'Medicine',
#  '123143354': 'Sociology',
#  '49705988': 'Medicine',
#  '1411474930': 'Medicine',
#  '152824521': 'Medicine',
#  '2109281698': 'Computer Science',
#  '3453317': 'Business',
#  '87649702': 'nan',
#  '6058558': 'Biology',
#  '114140135': 'Medicine',
#  '145854825': 'Chemistry',
#  '2454490': 'Computer Science',
#  '2196725176': 'Medicine',
#  '153284029': 'Economics',
#  '144321516': 'Computer Science',
#  '1753507': 'Computer Science',
#  '5450685': 'Political Science',
#  '15373768': 'Medicine',
#  '50352824': 'Economics',
#  '31288463': 'Materials Science',
#  '144435752': 'Computer Science',
#  '2115701971': 'Computer Science',
#  '2058479063': 'Biology',
#  '3930168': 'Environmental Science',
#  '49170011': 'Medicine',
#  '1401262304': 'Psychology',
#  '2069711111': 'Psychology',
#  '145546796': 'Biology',
#  '50818213': 'Computer Science',
#  '2046872053': 'Computer Science',
#  '3105979': 'Computer Science',
#  '2067834886': 'Biology',
#  '8690209': 'nan',
#  ...}

# %%
test1 = nx.get_node_attributes(G, 'field')
#test2 = nx.get_node_attributes(G, 'field2')
test1
# Out:
# {'1398627592': 'unknonwn',
#  '144562407': 'Physics',
#  '2060837062': 'unknonwn',
#  '31517266': 'unknonwn',
#  '4331724': 'unknonwn',
#  '91015314': 'unknonwn',
#  '4599086': 'unknonwn',
#  '46351403': 'unknonwn',
#  '2082324637': 'unknonwn',
#  '47717878': 'unknonwn',
#  '1964030928': 'unknonwn',
#  '2057087436': 'Psychology',
#  '4543142': 'unknonwn',
#  '5427387': 'unknonwn',
#  '4391310': 'unknonwn',
#  '51477263': 'unknonwn',
#  '2122607910': 'unknonwn',
#  '2186155276': 'unknonwn',
#  '1805545': 'Computer Science',
#  '66668960': 'unknonwn',
#  '1485004000': 'unknonwn',
#  '1729247675': 'Psychology',
#  '1729470864': 'unknonwn',
#  '1943370': 'Psychology',
#  '1398514748': 'unknonwn',
#  '22211632': 'unknonwn',
#  '1877662': 'unknonwn',
#  '2124442888': 'unknonwn',
#  '1955727': 'Computer Science',
#  '80273596': 'unknonwn',
#  '15703048': 'Psychology',
#  '38049428': 'unknonwn',
#  '3007050': 'Medicine',
#  '5445728': 'Medicine',
#  '3877237': 'Medicine',
#  '4376787': 'unknonwn',
#  '36205933': 'unknonwn',
#  '90841871': 'Medicine',
#  '1392941586': 'Psychology',
#  '34392925': 'unknonwn',
#  '113696172': 'unknonwn',
#  '2186154866': 'Psychology',
#  '152347103': 'Physics',
#  '30636552': 'Physics',
#  '11165750': 'unknonwn',
#  '50480210': 'Psychology',
#  '27321682': 'unknonwn',
#  '33974871': 'unknonwn',
#  '2122612554': 'unknonwn',
#  '2186155467': 'unknonwn',
#  '23603146': 'unknonwn',
#  '66577693': 'Medicine',
#  '1879631193': 'unknonwn',
#  '97888036': 'Psychology',
#  '1382075079': 'unknonwn',
#  '2122616593': 'unknonwn',
#  '48797032': 'unknonwn',
#  '2237559': 'unknonwn',
#  '46714697': 'Computer Science',
#  '102511439': 'unknonwn',
#  '3363887': 'unknonwn',
#  '36892108': 'Psychology',
#  '101680451': 'unknonwn',
#  '2122616999': 'Psychology',
#  '2504446': 'Medicine',
#  '39954198': 'unknonwn',
#  '2169959': 'unknonwn',
#  '9872116': 'unknonwn',
#  '82030779': 'unknonwn',
#  '9647308': 'Medicine',
#  '2633181': 'unknonwn',
#  '40607046': 'unknonwn',
#  '19292454': 'unknonwn',
#  '38365599': 'Medicine',
#  '2047525503': 'Psychology',
#  '2122617537': 'unknonwn',
#  '146670995': 'unknonwn',
#  '98196789': 'unknonwn',
#  '134626992': 'unknonwn',
#  '1381170185': 'unknonwn',
#  '1733303': 'unknonwn',
#  '2146531': 'unknonwn',
#  '145904081': 'unknonwn',
#  '2135126305': 'unknonwn',
#  '144911505': 'unknonwn',
#  '3629793': 'unknonwn',
#  '144476509': 'unknonwn',
#  '2122607241': 'unknonwn',
#  '103598469': 'unknonwn',
#  '145976303': 'Computer Science',
#  '1728462': 'Computer Science',
#  '2098647': 'unknonwn',
#  '151466092': 'unknonwn',
#  '47328954': 'unknonwn',
#  '48821788': 'unknonwn',
#  '145688284': 'unknonwn',
#  '5353005': 'unknonwn',
#  '1941859672': 'Psychology',
#  '2983925': 'unknonwn',
#  '2121175998': 'unknonwn',
#  '5934881': 'unknonwn',
#  '2139594793': 'Medicine',
#  '66704686': 'unknonwn',
#  '2052011221': 'unknonwn',
#  '4745051': 'unknonwn',
#  '1394624684': 'Psychology',
#  '46274926': 'unknonwn',
#  '1695840': 'unknonwn',
#  '1841612': 'unknonwn',
#  '112985523': 'unknonwn',
#  '2001444': 'unknonwn',
#  '115677083': 'unknonwn',
#  '2041852653': 'Psychology',
#  '114448918': 'unknonwn',
#  '35068280': 'unknonwn',
#  '2082636010': 'unknonwn',
#  '40526243': 'Psychology',
#  '2147116720': 'unknonwn',
#  '5666172': 'Medicine',
#  '152117799': 'Psychology',
#  '2068877856': 'unknonwn',
#  '1726081': 'unknonwn',
#  '31987589': 'unknonwn',
#  '14707013': 'unknonwn',
#  '48646405': 'unknonwn',
#  '2070849939': 'Psychology',
#  '2883285': 'unknonwn',
#  '115033215': 'unknonwn',
#  '7382311': 'unknonwn',
#  '145304581': 'unknonwn',
#  '38374176': 'Psychology',
#  '2110341354': 'Medicine',
#  '35256485': 'unknonwn',
#  '118917349': 'Psychology',
#  '4771844': 'Psychology',
#  '3151951': 'unknonwn',
#  '52388855': 'Physics',
#  '2016220783': 'Psychology',
#  '39919216': 'Psychology',
#  '153430607': 'unknonwn',
#  '1790415': 'Medicine',
#  '113315598': 'Medicine',
#  '3353606': 'unknonwn',
#  '2147546': 'Psychology',
#  '89826790': 'unknonwn',
#  '46920486': 'Economics',
#  '46942132': 'unknonwn',
#  '51451393': 'unknonwn',
#  '5429136': 'unknonwn',
#  '2108427312': 'unknonwn',
#  '2564269': 'unknonwn',
#  '145837228': 'unknonwn',
#  '48584150': 'Business',
#  '81359296': 'unknonwn',
#  '98781066': 'Psychology',
#  '5370509': 'Psychology',
#  '5919407': 'unknonwn',
#  '116988892': 'unknonwn',
#  '6522425': 'unknonwn',
#  '3988495': 'Medicine',
#  '41077180': 'unknonwn',
#  '1684197': 'unknonwn',
#  '1756679': 'Computer Science',
#  '31285768': 'unknonwn',
#  '3640778': 'unknonwn',
#  '1405590382': 'unknonwn',
#  '2181565120': 'unknonwn',
#  '115056203': 'unknonwn',
#  '7327053': 'unknonwn',
#  '1396794108': 'unknonwn',
#  '47792665': 'unknonwn',
#  '1844541': 'Psychology',
#  '2714926': 'unknonwn',
#  '1801346': 'unknonwn',
#  '3244651': 'unknonwn',
#  '46219674': 'Physics',
#  '50279051': 'unknonwn',
#  '81315701': 'Psychology',
#  '2117702453': 'unknonwn',
#  '2060679236': 'Political Science',
#  '5587812': 'Medicine',
#  '150317493': 'unknonwn',
#  '48909573': 'Psychology',
#  '1735847': 'unknonwn',
#  '1785673': 'unknonwn',
#  '1909879921': 'unknonwn',
#  '52036783': 'Psychology',
#  '2900564': 'unknonwn',
#  '92517933': 'unknonwn',
#  '145165884': 'unknonwn',
#  '3488155': 'Medicine',
#  '5769596': 'unknonwn',
#  '117612913': 'unknonwn',
#  '47375618': 'Physics',
#  '80717552': 'Psychology',
#  '1999935': 'Computer Science',
#  '87420403': 'Computer Science',
#  '49734494': 'unknonwn',
#  '1619938751': 'unknonwn',
#  '31938009': 'unknonwn',
#  '144460513': 'Medicine',
#  '15795494': 'unknonwn',
#  '4524377': 'Psychology',
#  '89507900': 'unknonwn',
#  '40560711': 'Psychology',
#  '1398967834': 'Medicine',
#  '152293976': 'Physics',
#  '6774521': 'Physics',
#  '145846140': 'unknonwn',
#  '2121144761': 'unknonwn',
#  '1684032': 'unknonwn',
#  '2113354821': 'unknonwn',
#  '117408200': 'Psychology',
#  '40427472': 'Psychology',
#  '118763457': 'unknonwn',
#  '144868645': 'unknonwn',
#  '40526973': 'Medicine',
#  '4735951': 'unknonwn',
#  '145454902': 'unknonwn',
#  '4796432': 'unknonwn',
#  '5551380': 'unknonwn',
#  '9616825': 'unknonwn',
#  '1398967816': 'unknonwn',
#  '3025976': 'unknonwn',
#  '148065609': 'Psychology',
#  '2102115789': 'unknonwn',
#  '4527578': 'unknonwn',
#  '48908983': 'unknonwn',
#  '10648037': 'unknonwn',
#  '2124272652': 'Economics',
#  '2016561': 'unknonwn',
#  '51229932': 'unknonwn',
#  '47854603': 'unknonwn',
#  '145647476': 'Computer Science',
#  '69947993': 'unknonwn',
#  '4031304': 'unknonwn',
#  '6709003': 'Medicine',
#  '2207482': 'Medicine',
#  '3560702': 'unknonwn',
#  '4950613': 'unknonwn',
#  '5489181': 'unknonwn',
#  '2069292988': 'unknonwn',
#  '1741044': 'unknonwn',
#  '2114151025': 'unknonwn',
#  '2525166': 'unknonwn',
#  '47608025': 'unknonwn',
#  '4024900': 'unknonwn',
#  '1740882': 'unknonwn',
#  '2260842': 'unknonwn',
#  '153631636': 'unknonwn',
#  '82567042': 'Psychology',
#  '2172234799': 'unknonwn',
#  '6728229': 'unknonwn',
#  '10689136': 'unknonwn',
#  '3776828': 'unknonwn',
#  '2138455174': 'unknonwn',
#  '119380506': 'unknonwn',
#  '7768645': 'unknonwn',
#  '39890606': 'unknonwn',
#  '4049176': 'unknonwn',
#  '1397938346': 'Psychology',
#  '145084900': 'Psychology',
#  '145191205': 'Psychology',
#  '20481967': 'unknonwn',
#  '144065562': 'Computer Science',
#  '2413779': 'unknonwn',
#  '145386473': 'unknonwn',
#  '2180819374': 'Economics',
#  '89315564': 'Computer Science',
#  '2122614503': 'unknonwn',
#  '1513198345': 'Medicine',
#  '2067551527': 'unknonwn',
#  '2572338': 'Medicine',
#  '4068043': 'unknonwn',
#  '10066085': 'unknonwn',
#  '2088787': 'unknonwn',
#  '32980371': 'unknonwn',
#  '38730378': 'unknonwn',
#  '103696363': 'Computer Science',
#  '145432486': 'unknonwn',
#  '2157094964': 'Medicine',
#  '145038874': 'unknonwn',
#  '122709529': 'Psychology',
#  '14066796': 'Psychology',
#  '4996359': 'unknonwn',
#  '66243262': 'unknonwn',
#  '11012699': 'unknonwn',
#  '2057472805': 'Psychology',
#  '2101287659': 'unknonwn',
#  '36514565': 'unknonwn',
#  '1414164803': 'unknonwn',
#  '40961987': 'unknonwn',
#  '123681972': 'Medicine',
#  '1379788244': 'unknonwn',
#  '82865687': 'Psychology',
#  '5129342': 'Medicine',
#  '7478863': 'unknonwn',
#  '1483813404': 'Psychology',
#  '35532974': 'Psychology',
#  '1851144': 'Medicine',
#  '2052614922': 'Computer Science',
#  '40009100': 'unknonwn',
#  '134190328': 'Psychology',
#  '145053627': 'Medicine',
#  '2138557083': 'unknonwn',
#  '2026107741': 'Psychology',
#  '21479764': 'unknonwn',
#  '145228093': 'unknonwn',
#  '2109084789': 'Computer Science',
#  '2082426': 'unknonwn',
#  '48606797': 'Medicine',
#  '115609299': 'unknonwn',
#  '4087076': 'unknonwn',
#  '1401909927': 'unknonwn',
#  '2277974': 'Economics',
#  '3600084': 'Psychology',
#  '67110175': 'unknonwn',
#  '12994972': 'unknonwn',
#  '2065011084': 'unknonwn',
#  '114596249': 'Psychology',
#  '3018957': 'Psychology',
#  '2087660922': 'unknonwn',
#  '2150414865': 'Psychology',
#  '1404388312': 'unknonwn',
#  '2044924718': 'Psychology',
#  '3526634': 'Psychology',
#  '46181760': 'unknonwn',
#  '1394655681': 'unknonwn',
#  '2108713499': 'Psychology',
#  '5060754': 'unknonwn',
#  '4359607': 'unknonwn',
#  '84490026': 'Psychology',
#  '1571581563': 'Psychology',
#  '2146667577': 'unknonwn',
#  '5934191': 'Medicine',
#  '3002236': 'unknonwn',
#  '33782404': 'Medicine',
#  '2176390': 'unknonwn',
#  '2146839094': 'unknonwn',
#  '3433697': 'Psychology',
#  '2071206993': 'unknonwn',
#  '65960877': 'Computer Science',
#  '1729276291': 'unknonwn',
#  '4530292': 'unknonwn',
#  '8272851': 'unknonwn',
#  '1388156299': 'unknonwn',
#  '1699604116': 'unknonwn',
#  '1733268': 'Computer Science',
#  '2142238578': 'unknonwn',
#  '3489922': 'Economics',
#  '3304879': 'Art',
#  '39393997': 'unknonwn',
#  '115717065': 'Psychology',
#  '2122610734': 'unknonwn',
#  '2186154814': 'Psychology',
#  '5961668': 'Psychology',
#  '102583371': 'Computer Science',
#  '103831391': 'Business',
#  '2066428236': 'Psychology',
#  '2114751': 'unknonwn',
#  '3285442': 'unknonwn',
#  '48597643': 'unknonwn',
#  '103447626': 'unknonwn',
#  '35769716': 'Psychology',
#  '118400711': 'unknonwn',
#  '2122599582': 'Psychology',
#  '1828905': 'unknonwn',
#  '2189018924': 'unknonwn',
#  '20984060': 'Psychology',
#  '47979096': 'unknonwn',
#  '145861075': 'Medicine',
#  '6192484': 'unknonwn',
#  '8360645': 'unknonwn',
#  '2268731': 'unknonwn',
#  '49899948': 'unknonwn',
#  '88263088': 'unknonwn',
#  '113229740': 'unknonwn',
#  '145975946': 'unknonwn',
#  '153062368': 'unknonwn',
#  '1666166974': 'unknonwn',
#  '51034966': 'unknonwn',
#  '5120903': 'unknonwn',
#  '2186154653': 'unknonwn',
#  '2186155294': 'unknonwn',
#  '1413507802': 'unknonwn',
#  '34122064': 'unknonwn',
#  '1396373573': 'unknonwn',
#  '2142386075': 'unknonwn',
#  '120703508': 'unknonwn',
#  '2304832': 'unknonwn',
#  '2110344784': 'Medicine',
#  '5271135': 'unknonwn',
#  '6873478': 'Medicine',
#  '1576240700': 'Psychology',
#  '6395097': 'Chemistry',
#  '143950311': 'Medicine',
#  '37744357': 'unknonwn',
#  '2226198': 'unknonwn',
#  '47171148': 'Psychology',
#  '144167157': 'unknonwn',
#  '1506961387': 'unknonwn',
#  '46206273': 'unknonwn',
#  '69036661': 'Physics',
#  '1896793': 'unknonwn',
#  '2031287': 'unknonwn',
#  '5095563': 'Medicine',
#  '2122612628': 'unknonwn',
#  '35330018': 'unknonwn',
#  '34618337': 'unknonwn',
#  '9187168': 'unknonwn',
#  '2190201': 'Medicine',
#  '2112283221': 'Psychology',
#  '5983253': 'unknonwn',
#  '117813413': 'Psychology',
#  '1577376476': 'unknonwn',
#  '2121175596': 'Psychology',
#  '32495697': 'Psychology',
#  '3449025': 'Linguistics',
#  '35351287': 'unknonwn',
#  '2150115388': 'Psychology',
#  '52229960': 'unknonwn',
#  '116651712': 'unknonwn',
#  '2172979996': 'unknonwn',
#  '1394219580': 'Computer Science',
#  '1746338': 'unknonwn',
#  '1944397': 'unknonwn',
#  '49584865': 'Medicine',
#  '7987468': 'unknonwn',
#  '10306428': 'Medicine',
#  '1400937384': 'unknonwn',
#  '1711849': 'Psychology',
#  '2122443396': 'unknonwn',
#  '2111036632': 'Psychology',
#  '29776174': 'Psychology',
#  '73155726': 'unknonwn',
#  '1803701': 'unknonwn',
#  '6930855': 'unknonwn',
#  '7161411': 'unknonwn',
#  '2759221': 'Physics',
#  '30482440': 'unknonwn',
#  '1733565': 'unknonwn',
#  '1784327': 'unknonwn',
#  '30469921': 'unknonwn',
#  '2122617020': 'unknonwn',
#  '6451235': 'Psychology',
#  '2359794': 'Psychology',
#  '2092390836': 'Psychology',
#  '4105968': 'unknonwn',
#  '3008832': 'unknonwn',
#  '41033249': 'unknonwn',
#  '117519860': 'Economics',
#  '50386317': 'Psychology',
#  '1693341': 'Computer Science',
#  '3145906': 'Computer Science',
#  '122307405': 'unknonwn',
#  '145175763': 'unknonwn',
#  '1853748': 'unknonwn',
#  '71219243': 'unknonwn',
#  '153264908': 'unknonwn',
#  '1903670': 'Political Science',
#  '144039860': 'unknonwn',
#  '2047487638': 'Computer Science',
#  '2122611025': 'unknonwn',
#  '115797162': 'Psychology',
#  '113515467': 'unknonwn',
#  '2070889': 'Psychology',
#  '10995115': 'unknonwn',
#  '1702139': 'Computer Science',
#  '2187874856': 'unknonwn',
#  '38254507': 'unknonwn',
#  '8139009': 'Medicine',
#  '2124790770': 'Psychology',
#  '1380991330': 'unknonwn',
#  '1388814275': 'unknonwn',
#  '2143577': 'Medicine',
#  '143665076': 'Medicine',
#  '145479841': 'unknonwn',
#  '22205513': 'unknonwn',
#  '5873669': 'Medicine',
#  '2122616210': 'unknonwn',
#  '2186155657': 'unknonwn',
#  '2116167788': 'Psychology',
#  '2959591': 'unknonwn',
#  '3303861': 'Computer Science',
#  '20515823': 'Medicine',
#  '6458810': 'Medicine',
#  '2063980690': 'unknonwn',
#  '2138603647': 'unknonwn',
#  '1810784': 'unknonwn',
#  '29934805': 'unknonwn',
#  '1747107962': 'unknonwn',
#  '5785969': 'unknonwn',
#  '100960951': 'Psychology',
#  '29950178': 'Political Science',
#  '1381196996': 'unknonwn',
#  '3393419': 'unknonwn',
#  '4729617': 'unknonwn',
#  '144763736': 'unknonwn',
#  '1382885331': 'unknonwn',
#  '34415745': 'Medicine',
#  '1400323122': 'unknonwn',
#  '2123787488': 'Economics',
#  '11023892': 'unknonwn',
#  '2061123005': 'Medicine',
#  '39812858': 'unknonwn',
#  '81476954': 'Psychology',
#  '6737678': 'unknonwn',
#  '5191580': 'unknonwn',
#  '117134552': 'Psychology',
#  '2122612314': 'unknonwn',
#  '2071848833': 'unknonwn',
#  '1937285690': 'unknonwn',
#  '3559372': 'Medicine',
#  '4235481': 'unknonwn',
#  '52091150': 'Physics',
#  '5516840': 'unknonwn',
#  '1943022788': 'unknonwn',
#  '3673464': 'unknonwn',
#  '48732005': 'Psychology',
#  '6132700': 'Psychology',
#  '1403899443': 'Psychology',
#  '2939966': 'unknonwn',
#  '144572233': 'unknonwn',
#  '2146549118': 'unknonwn',
#  '83619793': 'unknonwn',
#  '117708810': 'unknonwn',
#  '2255965': 'unknonwn',
#  '1734682': 'Computer Science',
#  '2066690': 'Computer Science',
#  '1747970': 'unknonwn',
#  '1900211': 'unknonwn',
#  '66776475': 'unknonwn',
#  '102511875': 'unknonwn',
#  '4414550': 'unknonwn',
#  '1404400730': 'Medicine',
#  '2124572875': 'unknonwn',
#  '4861657': 'Medicine',
#  '2122616794': 'unknonwn',
#  '3256006': 'unknonwn',
#  '48421240': 'unknonwn',
#  '50523122': 'unknonwn',
#  '1735321': 'unknonwn',
#  '3068011': 'unknonwn',
#  '1910268': 'unknonwn',
#  '3304914': 'Economics',
#  '2186155280': 'Psychology',
#  '2618529': 'unknonwn',
#  '5513033': 'unknonwn',
#  '118887698': 'unknonwn',
#  '120334000': 'unknonwn',
#  '2082324898': 'unknonwn',
#  '145481571': 'Psychology',
#  '3472683': 'Psychology',
#  '46580287': 'unknonwn',
#  '7478778': 'unknonwn',
#  '1752905222': 'unknonwn',
#  '2122607480': 'Psychology',
#  '1691929': 'unknonwn',
#  '1403126205': 'unknonwn',
#  '4925500': 'unknonwn',
#  '35234639': 'unknonwn',
#  '3807562': 'unknonwn',
#  '6072863': 'unknonwn',
#  '2122599140': 'unknonwn',
#  '2157435': 'Psychology',
#  '2085039308': 'unknonwn',
#  '80653579': 'unknonwn',
#  '112947275': 'unknonwn',
#  '148107429': 'unknonwn',
#  '1738210': 'unknonwn',
#  '1751591': 'Computer Science',
#  '144578221': 'unknonwn',
#  '145512647': 'Computer Science',
#  '2750026': 'Psychology',
#  '49979996': 'Psychology',
#  '2074197': 'Psychology',
#  '4971920': 'unknonwn',
#  '1403758675': 'Medicine',
#  '1658898370': 'Psychology',
#  '1488659424': 'Computer Science',
#  '1736632': 'unknonwn',
#  '47533224': 'Medicine',
#  '98591128': 'unknonwn',
#  '122570892': 'unknonwn',
#  '4918888': 'unknonwn',
#  '148353380': 'unknonwn',
#  '39948742': 'unknonwn',
#  '5742018': 'Medicine',
#  '3437408': 'unknonwn',
#  '8115151': 'unknonwn',
#  '2112010856': 'unknonwn',
#  '6446775': 'Psychology',
#  '7773811': 'Psychology',
#  '1602255019': 'unknonwn',
#  '2111744567': 'unknonwn',
#  '3514700': 'Engineering',
#  '2111635037': 'unknonwn',
#  '153557345': 'unknonwn',
#  '9640058': 'Medicine',
#  '13560674': 'Medicine',
#  '34376509': 'unknonwn',
#  '39176756': 'Psychology',
#  '145472073': 'unknonwn',
#  '2071975681': 'Political Science',
#  '3199878': 'unknonwn',
#  '145512648': 'unknonwn',
#  '2561756': 'unknonwn',
#  '145237361': 'unknonwn',
#  '1927646': 'Computer Science',
#  '1687892': 'unknonwn',
#  '49272925': 'unknonwn',
#  '144882235': 'unknonwn',
#  '2102193554': 'unknonwn',
#  '2295920': 'unknonwn',
#  '47840930': 'Psychology',
#  '31798445': 'Environmental Science',
#  '46453660': 'unknonwn',
#  '50622576': 'unknonwn',
#  '2080099149': 'Psychology',
#  '1863307': 'unknonwn',
#  '2250628': 'Sociology',
#  '2476751': 'unknonwn',
#  '35564007': 'unknonwn',
#  '145551508': 'Physics',
#  '50878058': 'unknonwn',
#  '1727412': 'unknonwn',
#  '1942993781': 'Medicine',
#  '4801675': 'Medicine',
#  '4782008': 'unknonwn',
#  '3075047': 'unknonwn',
#  '3373421': 'unknonwn',
#  '115028766': 'unknonwn',
#  '2404771': 'unknonwn',
#  '2037790785': 'unknonwn',
#  '2077331851': 'unknonwn',
#  '2764609': 'unknonwn',
#  '4734173': 'unknonwn',
#  '1699605': 'unknonwn',
#  '3209837': 'unknonwn',
#  '144399837': 'Physics',
#  '2461135': 'Physics',
#  '144389329': 'unknonwn',
#  '3214219': 'unknonwn',
#  '4305898': 'unknonwn',
#  '88248521': 'Medicine',
#  '2122206615': 'unknonwn',
#  '4885179': 'unknonwn',
#  '5895317': 'unknonwn',
#  '51920200': 'unknonwn',
#  '6888909': 'unknonwn',
#  '2047731524': 'Economics',
#  '49342120': 'unknonwn',
#  '145310797': 'Physics',
#  '35307382': 'unknonwn',
#  '1702481': 'unknonwn',
#  '2065401214': 'unknonwn',
#  '49574151': 'unknonwn',
#  '1873286393': 'unknonwn',
#  '41076252': 'unknonwn',
#  '1716911': 'unknonwn',
#  '2754289': 'Medicine',
#  '2767430': 'unknonwn',
#  '11889613': 'unknonwn',
#  '49592899': 'unknonwn',
#  '46330445': 'Education',
#  '48938122': 'unknonwn',
#  '82041190': 'unknonwn',
#  '3352153': 'unknonwn',
#  '3157953': 'Psychology',
#  '3516118': 'Medicine',
#  '114309502': 'unknonwn',
#  '8003355': 'Art',
#  '2142196964': 'Medicine',
#  '2524172': 'unknonwn',
#  '72630048': 'unknonwn',
#  '5938832': 'unknonwn',
#  '81627350': 'Psychology',
#  '152572311': 'unknonwn',
#  '3863266': 'unknonwn',
#  '101788507': 'unknonwn',
#  '2076303096': 'unknonwn',
#  '2122614357': 'Psychology',
#  '2000187': 'Computer Science',
#  '9461483': 'unknonwn',
#  '39876154': 'Psychology',
#  '3697501': 'Medicine',
#  '1778398': 'Computer Science',
#  '2632078': 'Economics',
#  '47013143': 'unknonwn',
#  '2712804': 'unknonwn',
#  '46283208': 'unknonwn',
#  '2122241280': 'Psychology',
#  '2376550': 'Economics',
#  '2660799': 'unknonwn',
#  '13152609': 'unknonwn',
#  '38681589': 'unknonwn',
#  '116645083': 'Medicine',
#  '12720159': 'unknonwn',
#  '2122599291': 'Psychology',
#  '11920911': 'unknonwn',
#  '1704729': 'unknonwn',
#  '3324944': 'unknonwn',
#  '1989585': 'Psychology',
#  '2078564666': 'Psychology',
#  '37261151': 'unknonwn',
#  '1680354': 'unknonwn',
#  '1714996': 'unknonwn',
#  '48098508': 'unknonwn',
#  '8864672': 'unknonwn',
#  '2122612172': 'unknonwn',
#  '46190942': 'unknonwn',
#  '1684176': 'Computer Science',
#  '1716440': 'Computer Science',
#  '145548207': 'unknonwn',
#  '1997679722': 'unknonwn',
#  '89732564': 'unknonwn',
#  '6554785': 'unknonwn',
#  '2067571838': 'Psychology',
#  '2148496877': 'Psychology',
#  '145633895': 'Computer Science',
#  '1712103': 'Computer Science',
#  '49889222': 'Computer Science',
#  '117107073': 'unknonwn',
#  '91120234': 'Physics',
#  '2066730': 'unknonwn',
#  '35357393': 'unknonwn',
#  '2061265215': 'unknonwn',
#  '4903243': 'unknonwn',
#  '2005414875': 'unknonwn',
#  '1792682': 'unknonwn',
#  '3165818': 'unknonwn',
#  '10330676': 'unknonwn',
#  '41205187': 'Physics',
#  '1832860418': 'unknonwn',
#  '3923102': 'Medicine',
#  '2064297706': 'Medicine',
#  '3154478': 'Computer Science',
#  '46673132': 'unknonwn',
#  '153709709': 'Computer Science',
#  '1777283': 'Computer Science',
#  '8408197': 'Medicine',
#  '2153703275': 'Medicine',
#  '3782043': 'unknonwn',
#  '39002150': 'unknonwn',
#  '90442540': 'Physics',
#  '2122607203': 'unknonwn',
#  '14032351': 'unknonwn',
#  '1470636650': 'unknonwn',
#  '6371395': 'unknonwn',
#  '7011254': 'unknonwn',
#  '152369237': 'unknonwn',
#  '145298054': 'Computer Science',
#  '2354501': 'Sociology',
#  '2003945761': 'unknonwn',
#  '2240498': 'Psychology',
#  '145042957': 'unknonwn',
#  '6749091': 'Psychology',
#  '152595505': 'unknonwn',
#  '81730110': 'unknonwn',
#  '3624717': 'unknonwn',
#  '89985640': 'unknonwn',
#  '49279379': 'unknonwn',
#  '5784319': 'Psychology',
#  '2174910587': 'unknonwn',
#  '7003557': 'unknonwn',
#  '145580839': 'Computer Science',
#  '9261284': 'unknonwn',
#  '2685443': 'unknonwn',
#  '1749906': 'unknonwn',
#  '2464164': 'unknonwn',
#  '2107507325': 'unknonwn',
#  '5867556': 'unknonwn',
#  '47365863': 'unknonwn',
#  '1739159': 'unknonwn',
#  '2109957': 'unknonwn',
#  '2131047983': 'Medicine',
#  '121829468': 'unknonwn',
#  '3963146': 'Medicine',
#  '48686298': 'Medicine',
#  '11583899': 'unknonwn',
#  '27558311': 'unknonwn',
#  '144982204': 'unknonwn',
#  '2004364619': 'unknonwn',
#  '46180469': 'unknonwn',
#  '87069200': 'unknonwn',
#  '1999240111': 'unknonwn',
#  '2104898325': 'unknonwn',
#  '153129006': 'Computer Science',
#  '2852732': 'unknonwn',
#  '2107828714': 'Physics',
#  '4263558': 'Physics',
#  '5209814': 'unknonwn',
#  '51904698': 'unknonwn',
#  '1390172488': 'unknonwn',
#  '144217725': 'unknonwn',
#  '4354712': 'unknonwn',
#  '51879228': 'Medicine',
#  '3960883': 'Medicine',
#  '2186154636': 'Psychology',
#  '40578690': 'unknonwn',
#  '31877699': 'unknonwn',
#  '103615974': 'Physics',
#  '30019933': 'unknonwn',
#  '46663300': 'unknonwn',
#  '144372454': 'unknonwn',
#  '2186155617': 'Psychology',
#  '1403657977': 'unknonwn',
#  '1404645774': 'unknonwn',
#  '2364686': 'unknonwn',
#  '51258407': 'unknonwn',
#  '1746718': 'Psychology',
#  '145059003': 'unknonwn',
#  '3032636': 'unknonwn',
#  '1401045848': 'unknonwn',
#  '6756968': 'unknonwn',
#  '2122612672': 'Psychology',
#  '40897979': 'unknonwn',
#  '5498665': 'unknonwn',
#  '31676892': 'Psychology',
#  '52109205': 'unknonwn',
#  '2110810': 'unknonwn',
#  '6320944': 'unknonwn',
#  '39658867': 'Psychology',
#  '1409288772': 'unknonwn',
#  '2111224744': 'Economics',
#  '117042725': 'Psychology',
#  '4518656': 'unknonwn',
#  '7236546': 'unknonwn',
#  '2122615176': 'unknonwn',
#  '4887132': 'Psychology',
#  '32157118': 'unknonwn',
#  '1753652328': 'Psychology',
#  '145300266': 'unknonwn',
#  '16762280': 'Business',
#  '34813847': 'unknonwn',
#  '5282731': 'Physics',
#  '6425182': 'unknonwn',
#  '145085305': 'Computer Science',
#  '69498617': 'Computer Science',
#  '1382005256': 'unknonwn',
#  '13229609': 'Psychology',
#  '2122616350': 'unknonwn',
#  '6212028': 'unknonwn',
#  '6619544': 'unknonwn',
#  '2178415156': 'unknonwn',
#  '3486277': 'unknonwn',
#  '144110014': 'unknonwn',
#  '46491690': 'unknonwn',
#  '120972268': 'unknonwn',
#  '1779972': 'unknonwn',
#  '114205978': 'unknonwn',
#  '2269775': 'unknonwn',
#  '2537431': 'unknonwn',
#  '26681202': 'unknonwn',
#  '52139048': 'unknonwn',
#  '3484112': 'unknonwn',
#  '3487098': 'Economics',
#  '2138729058': 'unknonwn',
#  '2116163835': 'unknonwn',
#  '2064990932': 'unknonwn',
#  '2049085100': 'unknonwn',
#  '80916191': 'Biology',
#  '2091077618': 'Sociology',
#  '40387300': 'unknonwn',
#  '153481005': 'unknonwn',
#  '119835055': 'unknonwn',
#  '2122611084': 'unknonwn',
#  '143954415': 'unknonwn',
#  '4186210': 'Psychology',
#  '1755147': 'unknonwn',
#  '1784751': 'unknonwn',
#  '2110961881': 'Psychology',
#  '2359480': 'unknonwn',
#  '47082401': 'unknonwn',
#  '8121028': 'Psychology',
#  '1399739991': 'Medicine',
#  '67266295': 'unknonwn',
#  '34973214': 'unknonwn',
#  '2505272': 'Psychology',
#  '40632770': 'Psychology',
#  '1702030': 'unknonwn',
#  '2696361': 'unknonwn',
#  '1481735898': 'Medicine',
#  '5691238': 'Medicine',
#  '32249392': 'Medicine',
#  '40489435': 'Medicine',
#  '1712542': 'unknonwn',
#  '1740273': 'unknonwn',
#  '3603131': 'Physics',
#  '34604499': 'unknonwn',
#  '15568004': 'unknonwn',
#  '4642370': 'unknonwn',
#  '2165455': 'unknonwn',
#  '2144504121': 'unknonwn',
#  '6972400': 'unknonwn',
#  '143822105': 'unknonwn',
#  '1402788093': 'unknonwn',
#  '4355781': 'Medicine',
#  '47941628': 'Medicine',
#  '2598920': 'Medicine',
#  '94153989': 'unknonwn',
#  '7595780': 'unknonwn',
#  '5685777': 'unknonwn',
#  '46644233': 'unknonwn',
#  '145825234': 'unknonwn',
#  '2823330': 'unknonwn',
#  '120400306': 'unknonwn',
#  '3683760': 'unknonwn',
#  '25865074': 'Medicine',
#  '6150496': 'unknonwn',
#  '2121714328': 'Psychology',
#  '1712655': 'unknonwn',
#  '1717971': 'unknonwn',
#  '4698745': 'unknonwn',
#  '6930571': 'unknonwn',
#  '145201463': 'Computer Science',
#  '1990106153': 'unknonwn',
#  '3587759': 'unknonwn',
#  '8751029': 'unknonwn',
#  '1693022': 'Computer Science',
#  '2228676': 'unknonwn',
#  '2132696372': 'Psychology',
#  '38395120': 'unknonwn',
#  '6151004': 'unknonwn',
#  '2186155580': 'unknonwn',
#  '7405877': 'Psychology',
#  '145345023': 'Computer Science',
#  '1709595': 'unknonwn',
#  '2122452036': 'unknonwn',
#  '1694393': 'unknonwn',
#  '2633757': 'unknonwn',
#  '70980073': 'unknonwn',
#  '2064167734': 'Psychology',
#  '2079948545': 'unknonwn',
#  '145643522': 'unknonwn',
#  '145769716': 'unknonwn',
#  '117871796': 'unknonwn',
#  '2082059449': 'unknonwn',
#  '31175276': 'unknonwn',
#  '5612033': 'unknonwn',
#  '153245733': 'Psychology',
#  '1485807315': 'Psychology',
#  '1745451': 'Computer Science',
#  '88013307': 'unknonwn',
#  '3152369': 'unknonwn',
#  '1793035': 'unknonwn',
#  '2516889': 'Business',
#  '48054965': 'unknonwn',
#  '50450956': 'unknonwn',
#  '2163752': 'Computer Science',
#  '1382272510': 'unknonwn',
#  '4736287': 'unknonwn',
#  '6476639': 'unknonwn',
#  '143848638': 'unknonwn',
#  '7014473': 'unknonwn',
#  '2006862473': 'unknonwn',
#  '1742281679': 'unknonwn',
#  '2950043': 'Computer Science',
#  '29187646': 'unknonwn',
#  '35931702': 'unknonwn',
#  '2080197097': 'Political Science',
#  '2091576379': 'Political Science',
#  '79078883': 'unknonwn',
#  '144977963': 'Computer Science',
#  '1737241': 'Computer Science',
#  '37889961': 'unknonwn',
#  '113080620': 'unknonwn',
#  '119449362': 'unknonwn',
#  '2121164318': 'Psychology',
#  '2071234378': 'unknonwn',
#  '27094341': 'unknonwn',
#  '31228081': 'unknonwn',
#  '2110262231': 'Medicine',
#  '8444968': 'unknonwn',
#  '2122615706': 'Psychology',
#  '1403150891': 'unknonwn',
#  '46998993': 'unknonwn',
#  '35239203': 'Chemistry',
#  '25554238': 'unknonwn',
#  '49119769': 'Psychology',
#  '3271204': 'Medicine',
#  '120390745': 'unknonwn',
#  '2099150066': 'Psychology',
#  '152233784': 'unknonwn',
#  '3191034': 'unknonwn',
#  '40308695': 'unknonwn',
#  '2122607462': 'unknonwn',
#  '1795513': 'unknonwn',
#  '25294406': 'unknonwn',
#  '114666848': 'unknonwn',
#  '3969507': 'Physics',
#  '2696727': 'Computer Science',
#  '35212893': 'unknonwn',
#  '1786137': 'Computer Science',
#  '2725959': 'unknonwn',
#  '101362164': 'unknonwn',
#  '8266964': 'unknonwn',
#  '25248112': 'Medicine',
#  '6913994': 'Medicine',
#  '46234759': 'Medicine',
#  ...}

# %%
with open('CSS_name_field.pkl', 'wb') as f:
    pickle.dump(G, f)

# %%
nw.visualize(G)
# Out:
# (None, None)

# %%
cc = [len(c) for c in sorted(nx.connected_components(G), key=len, reverse=True)]
S = G.subgraph(max(nx.connected_components(G), key=len)).copy()

# %% [markdown]
# # Part 3: Properties of the real-world network of Computational Social Scientists

# %% [markdown]
# > _Exercise 2_:
# >
# > 2.1 _Random Network_: In this exercise we will create a Random Network as a ["null model"](https://en.wikipedia.org/wiki/Null_model) to investigate some properties of the Computational Social Scientists Network.
# > * Compute the value of _p_ such that the number of expected edges of the random network equals the number of edges in the Computational Social Scientists network (see equation 3.2 in your Network Science Book). What is the value of p? Compute the average value of the degree < k > (using the formula).
# > * Create a Random network with the same number of nodes as the Computational Social Scientists networks, and _p_ as computed above. Generate a random network by linking nodes in every possible pair with probability _p_. **Hint**: you can use the function [``np.random.uniform``](https://numpy.org/doc/stable/reference/random/generated/numpy.random.uniform.html) to draw samples from a uniform probability distribution.
# > * Visualize the network as you did for the Computational Social Scientists network in the exercise above (my version is below). Comment on the differences between the two.
# >
# > 2.2 _Degree Distribution_: In this exercise, we will compare the degree distribution of the real network and its random counterpart.
# > * Compute the distribution of degree for the random network using the numpy function ``np.histogram``. Bin your histogram using 10 linearly spaced bins. Remember to pass the parameter ``density=True``.
# > * Compute the distribution of degree for the Computational Social Scientists network using the numpy function ``np.histogram``. Bin your histogram using 10 logarithmically spaced bins. Remember to pass the parameter ``density=True``.
# > * Plot the two distributions you computed in steps 1. and 2. in the same figure as two line-graphs. Log-scale the x and y axes.
# > * Comment the figure. What are the differences between the two distributions? Why did I ask you to use two different types of binning?
# > * What is the average degree of the random and the real network? Comment on the relation between the two.
# >
# > 2.3 _Shortest Paths_: Here, we will check if the Computational Social Scientists Network is a small-world Network.
# > * Compute the average shortest path for the largest connected component of the Computational Social Scientists network (for a reminder of the definition of connected components, check [section 2.9 of the Network Science book](http://networksciencebook.com/chapter/2#connectedness)). You can use the following steps:
# >    * Use [``nx.algorithms.connected_components``](https://networkx.org/documentation/stable//reference/algorithms/generated/networkx.algorithms.components.connected_components.html) to find all connected components (it returns a list of subsets of the original set of nodes).
# >    * Consider the largest subset of nodes found in the step above. Build the subgraph of your original network containing those nodes exclusively, using [``nx.Graph.subgraph``](https://networkx.org/documentation/stable/reference/classes/generated/networkx.Graph.subgraph.html). This corresponds to your largest connected component (a.k.a [giant component](https://en.wikipedia.org/wiki/Giant_component)).
# > * Compute the average shortest path length of the giant component using [``nx.average_shortest_path_length``](https://networkx.org/documentation/networkx-1.3/reference/generated/networkx.average_shortest_path_length.html)
# > * Compute the average shortest path length for the giant component of the random network you built in exercise 2.1.
# > * Comment on the relation between the average shortest path length in the real and the random networks. Can you conclude that the small-world property apply to the Computational Social Scientists network?
# >
# > 2.4 _Clustering_: Here, we will compare the clustering coefficient in the Computational Social Scientists Network and its random counterpart.
# > * Compute the clustering coefficient for all nodes in the random network, using the formula 2.15 in your book. **Hint**: To check your method, you can compare your results with those obtained using the networkx [``clustering``](https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.cluster.clustering.html#networkx.algorithms.cluster.clustering) function.
# > * Compute the average clustering across nodes of the random network. Is it consistent with the analytical prediction (network science book equation 3.21)?
# > * Compute the average clustering coefficient for the Computational Social Scientists network. How does it compare to its random counterpart? Is it something you would expect? Why?
#
#
# <img src="https://github.com/lalessan/comsocsci2021/raw/master/files/random_network.png" alt="Drawing" style="width: 800px;"/>
